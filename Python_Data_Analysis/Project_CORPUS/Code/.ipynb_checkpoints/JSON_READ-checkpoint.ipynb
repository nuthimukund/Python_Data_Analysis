# %% [markdown]
# ### Reading all of the JSON files Reviews and ProductInfo into a single Pandas dataframe

# %%
#Importing libraries
import json,pandas as pd
import glob

# %%
#Reading the sample file
with open('Sample_Data/B000E7T7JO.json', 'rb') as file:
    File = json.load(file)

# %%
#Printing the File that was read in the previous command
print(File['Reviews'][:2])
print(File['ProductInfo'])
# Out:
# [{u'Author': u'Renee A.', u'ReviewID': u'R1XV15PBPT4F3N', u'Overall': u'4.0', u'Content': u'the one i was sent was the silver not blue version but overall, i liked the phone and it was mainly due to the simplicity of the phone.pros:speakerphonespacing of keysinside screenreceptionbattery lifecons:outside display of the contact name and the word "calling" next to it.... it seems redundant to have that.can only have individual ringtones if on the phone itself and not on SIM card.simple functions difficult to find without the help of manual.the cons are minor if you don\'t mind a few gliches but i recommend this phone for those who want a simple phone with quality over quantity.', u'Title': u'Good and simple phone.', u'Date': u'May 2, 2006'}, {u'Author': u'Fortran guy', u'ReviewID': u'R2NZE1TJ8U4OM6', u'Overall': u'3.0', u'Content': u'I bought this phone mainly to use in Italy for extended visits and plan to get an Italian SIM card. The phone itself works well (I tend to like Motorola phones -- others may not) and the quad band capability should ensure compatibility with European wireless networks.One big selling point of this phone was Amazon\'s claim that it was unlocked.  However, after trying two SIM cards from provides other than AT&T;/Cingular (one from an Italian provider and one from a Hong Kong provider) the phone is quite definitely LOCKED as it asks for a subsidy code when you boot up with a non-AT&T; SIM card.  So I will likely have to fork over another 15-20$ to get a code to unlock it from a third party.I think others have had similar problems --- as the phone was supposedly sold directly by Amazon (but I am sure they are using a third-party supplier), my suggestion to their quality control department is to pay a little more serious attention to this issue of selling locked phones as being "unlocked".One other thing -- it appears one may need to buy the software necessary to use computer-communication features on this phone (but I have not done a deep search on the Web to see if the software can be found for free --- what I know is my XP-system does not have a device driver to mount the phone and the phone manual indicates one needs to purchase such software).', u'Title': u'OK phone --- but it is *NOT* unlocked', u'Date': u'December 27, 2008'}]
# {u'Price': u'$149.99', u'ProductID': u'B000E7T7JO', u'Features': u"This unlocked cell phone is compatible with GSM carriers like AT&T; and T-Mobile. Not all carrier features may be supported. It will not work with CDMA carriers like Verizon Wireless, Alltel and Sprint.\nQuad-band GSM cell phone compatible with 850/900/1800/1900 frequencies and GPRS capabilities\nDual LCD screens; integrated speakerphone; supports polyphonic and MP3 ringtones; SMS text messaging; organizer tools; USB connectivity\nUp to 11.25 hours of talk time and 700 hours of standby\nWhat's in the Box: Handset, battery, battery door, travel charger, user manual", u'ImgURL': u'http://ecx.images-amazon.com/images/I/412XG8654YL._SY300_.jpg', u'Name': u'Motorola V190 Unlocked Phone Quad-Band GSM, MP3, and SpeakerPhone--U.S. Version with Warranty (Black)'}

# %% [markdown]
# As we can see in the JSON data file there are two different keys, 'Reviews' and 'ProductInfo'
#
# 1. Reviews - The value for the Reviews is an array of dictionaries which contains the reviews by different authors for the same product.
# 2. ProductInfo - The value for ProductInfo describes about the product to which the reviews were written.
#
# Using the following code we are reading these two keys into different dataframes and concatenating them to form a final dataset which can used for further text analytics.

# %%
df_r = pd.DataFrame.from_dict(File['Reviews']) #Reading the Reviews into a dataframe
df_r.head()
# Out:
#             Author                                            Content  \
# 0         Renee A.  the one i was sent was the silver not blue ver...
# 1      Fortran guy  I bought this phone mainly to use in Italy for...
# 2     R. Truderung  Easy to uselong battery lifegood features if l...
# 3       A. Wiedlea  The phone was not unlocked as advertised, and ...
# 4  Lost Soul "TKW"  This is an excellent basic phone.  No complain...
#
#                 Date Overall        ReviewID  \
# 0        May 2, 2006     4.0  R1XV15PBPT4F3N
# 1  December 27, 2008     3.0  R2NZE1TJ8U4OM6
# 2      June 24, 2006     5.0  R2QVOAB2V519JB
# 3  November 22, 2008     1.0  R1W6775KPGPV8U
# 4     April 25, 2008     5.0   RLE7RNJVY2LB2
#
#                                    Title
# 0                 Good and simple phone.
# 1  OK phone --- but it is *NOT* unlocked
# 2                          simple & easy
# 3                           Not Unlocked
# 4              Motorola V-190 Cell Phone

# %%
product_info = File['ProductInfo'] #Reading the ProductInfo into a Dictionary variable
print(type(product_info))
product_info
# Out:
# <type 'dict'>
# {u'Features': u"This unlocked cell phone is compatible with GSM carriers like AT&T; and T-Mobile. Not all carrier features may be supported. It will not work with CDMA carriers like Verizon Wireless, Alltel and Sprint.\nQuad-band GSM cell phone compatible with 850/900/1800/1900 frequencies and GPRS capabilities\nDual LCD screens; integrated speakerphone; supports polyphonic and MP3 ringtones; SMS text messaging; organizer tools; USB connectivity\nUp to 11.25 hours of talk time and 700 hours of standby\nWhat's in the Box: Handset, battery, battery door, travel charger, user manual",
#  u'ImgURL': u'http://ecx.images-amazon.com/images/I/412XG8654YL._SY300_.jpg',
#  u'Name': u'Motorola V190 Unlocked Phone Quad-Band GSM, MP3, and SpeakerPhone--U.S. Version with Warranty (Black)',
#  u'Price': u'$149.99',
#  u'ProductID': u'B000E7T7JO'}

# %%
new_df = pd.concat([df_r, pd.DataFrame(product_info, index=df_r.index)], axis=1) #Concatenating Reviews and ProductInfo
new_df.head()
# Out:
#             Author                                            Content  \
# 0         Renee A.  the one i was sent was the silver not blue ver...
# 1      Fortran guy  I bought this phone mainly to use in Italy for...
# 2     R. Truderung  Easy to uselong battery lifegood features if l...
# 3       A. Wiedlea  The phone was not unlocked as advertised, and ...
# 4  Lost Soul "TKW"  This is an excellent basic phone.  No complain...
#
#                 Date Overall        ReviewID  \
# 0        May 2, 2006     4.0  R1XV15PBPT4F3N
# 1  December 27, 2008     3.0  R2NZE1TJ8U4OM6
# 2      June 24, 2006     5.0  R2QVOAB2V519JB
# 3  November 22, 2008     1.0  R1W6775KPGPV8U
# 4     April 25, 2008     5.0   RLE7RNJVY2LB2
#
#                                    Title  \
# 0                 Good and simple phone.
# 1  OK phone --- but it is *NOT* unlocked
# 2                          simple & easy
# 3                           Not Unlocked
# 4              Motorola V-190 Cell Phone
#
#                                             Features  \
# 0  This unlocked cell phone is compatible with GS...
# 1  This unlocked cell phone is compatible with GS...
# 2  This unlocked cell phone is compatible with GS...
# 3  This unlocked cell phone is compatible with GS...
# 4  This unlocked cell phone is compatible with GS...
#
#                                               ImgURL  \
# 0  http://ecx.images-amazon.com/images/I/412XG865...
# 1  http://ecx.images-amazon.com/images/I/412XG865...
# 2  http://ecx.images-amazon.com/images/I/412XG865...
# 3  http://ecx.images-amazon.com/images/I/412XG865...
# 4  http://ecx.images-amazon.com/images/I/412XG865...
#
#                                                 Name    Price   ProductID
# 0  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 1  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 2  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 3  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 4  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO

# %% [markdown]
# #### Now that we have a dataframe in which Reviews and ProductInfo is combined, we are now applying the same logic to all JSON files in the directory to form a huge dataframe which can be used for text analytics.

# %% [markdown]
# ### Creating data frame from all the files in the Sample data folder

# %%
Final_df = pd.DataFrame()
read_files = glob.glob("Sample_Data/*.json")
for i in range(0,len(read_files)):
    with open(read_files[i], 'rb') as x:
        JSONFILE = json.load(x)
    review_df = pd.DataFrame(JSONFILE['Reviews'])
    product = JSONFILE['ProductInfo']
    combined_df = pd.concat([review_df, pd.DataFrame(product, index=review_df.index)], axis=1)
    Final_df = pd.concat([Final_df, combined_df]) 

Final_df.head()
# Out:
#             Author                                            Content  \
# 0         Renee A.  the one i was sent was the silver not blue ver...
# 1      Fortran guy  I bought this phone mainly to use in Italy for...
# 2     R. Truderung  Easy to uselong battery lifegood features if l...
# 3       A. Wiedlea  The phone was not unlocked as advertised, and ...
# 4  Lost Soul "TKW"  This is an excellent basic phone.  No complain...
#
#                 Date Overall        ReviewID  \
# 0        May 2, 2006     4.0  R1XV15PBPT4F3N
# 1  December 27, 2008     3.0  R2NZE1TJ8U4OM6
# 2      June 24, 2006     5.0  R2QVOAB2V519JB
# 3  November 22, 2008     1.0  R1W6775KPGPV8U
# 4     April 25, 2008     5.0   RLE7RNJVY2LB2
#
#                                    Title  \
# 0                 Good and simple phone.
# 1  OK phone --- but it is *NOT* unlocked
# 2                          simple & easy
# 3                           Not Unlocked
# 4              Motorola V-190 Cell Phone
#
#                                             Features  \
# 0  This unlocked cell phone is compatible with GS...
# 1  This unlocked cell phone is compatible with GS...
# 2  This unlocked cell phone is compatible with GS...
# 3  This unlocked cell phone is compatible with GS...
# 4  This unlocked cell phone is compatible with GS...
#
#                                               ImgURL  \
# 0  http://ecx.images-amazon.com/images/I/412XG865...
# 1  http://ecx.images-amazon.com/images/I/412XG865...
# 2  http://ecx.images-amazon.com/images/I/412XG865...
# 3  http://ecx.images-amazon.com/images/I/412XG865...
# 4  http://ecx.images-amazon.com/images/I/412XG865...
#
#                                                 Name    Price   ProductID
# 0  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 1  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 2  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 3  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO
# 4  Motorola V190 Unlocked Phone Quad-Band GSM, MP...  $149.99  B000E7T7JO

# %% [markdown]
# ### Creating and saving data frame from all the files in the Mobilephone folder (complete data ~130mb)

# %%
Final_df1 = pd.DataFrame()
read_files1 = glob.glob("/media/mukund/New Volume/Datasets/AmazonReviews/mobilephone/*.json")
for i in range(0,len(read_files1)):
    with open(read_files1[i], 'rb') as x:
        JSONFILE1 = json.load(x)
    review_df1 = pd.DataFrame(JSONFILE1['Reviews'])
    product1 = JSONFILE1['ProductInfo']
    combined_df1 = pd.concat([review_df1, pd.DataFrame(product1, index=review_df1.index)], axis=1)
    Final_df1 = pd.concat([Final_df1, combined_df1]) 

Final_df1.head()
# Out:
#          Author                                            Content  \
# 0        Dustin  Product came exactly as described and would re...
# 1     Lancerman  I am very pleased with the phone we received. ...
# 2       Maranda  The Samsung Galazy S3 is one of the best phone...
# 0      Jackie C  The television was a refurbished one, and for ...
# 1  Sonja Trokey  Delivery was very prompt.  The picture of this...
#
#              Date Features ImgURL  Name Overall Price   ProductID  \
# 0  March 10, 2014     None   None  None     5.0  None  1466736038
# 1  March 27, 2014     None   None  None     5.0  None  1466736038
# 2   April 3, 2014     None   None  None     5.0  None  1466736038
# 0  April 13, 2014     None   None  None     4.0  None  8987029395
# 1   April 1, 2014     None   None  None     4.0  None  8987029395
#
#          ReviewID                                   Title
# 0   RYYNWQWW6LAC1                                   Great
# 1  R2G160TW2JWGD8                        Excellent phone.
# 2  R3P9IS2JNG68K2          As described and a great phone
# 0  R3LDJA7HU2Q0FS           nice television for the price
# 1   RAQB0MR9LGA2G  Service and product quality very good.

# %%
Final_df1.count()
# Out:
# Author       185718
# Content      185993
# Date         186015
# Features     172753
# ImgURL       175331
# Name         175331
# Overall      186016
# Price        175257
# ProductID    186016
# ReviewID     186016
# Title        186016
# dtype: int64

# %%
#Resetting the Index as it is not sequential
Final_df1 = Final_df1.reset_index()
# Out:
#         index                                       Author  \
# 0           0                                       Dustin
# 1           1                                    Lancerman
# 2           2                                      Maranda
# 3           0                                     Jackie C
# 4           1                                 Sonja Trokey
# 5           0                                          RrB
# 6           1                                        Peter
# 7           2                         Phone does not work!
# 8           3                                        dm301
# 9           4                                  Julie Crowe
# 10          5                                          rpv
# 11          6                                  not working
# 12          7                                        Patty
# 13          8                                   Air filter
# 14          9                              superxlinaah401
# 15         10                                        Ellen
# 16         11                                   dariojelis
# 17          0                 Rodolfo Rubio Mtz "Dogrubio"
# 18          1                                James Kinsley
# 19          2                                  James Clark
# 20          3                                         M.B.
# 21          4                                         None
# 22          5                                         None
# 23          6                            F. A. Almeida Paz
# 24          7                                         None
# 25          0  Tobin Coziahr "Intergalactic bounty hunter"
# 26          1                                         None
# 27          2                                         None
# 28          3                 Gabriel Ha "enlightenedmonk"
# 29          4                                         None
# ...       ...                                          ...
# 185986     25                                           SM
# 185987     26                                  Kaitlynn W.
# 185988     27                               James Bradshaw
# 185989     28                                      Kristin
# 185990      0                               Johnny Saigon®
# 185991      1                                 Carlos Julio
# 185992      2                                Diego Ramirez
# 185993      3                                        Al Q.
# 185994      4                   Jaime Eduardo Lopez Zarate
# 185995      5                           ALEXANDRU NOVITCHI
# 185996      6                                      Roynier
# 185997      7                                      Barry R
# 185998      8                               Yehezkel Yosef
# 185999      9                      Antonia Yepez "Moraima"
# 186000     10                             Rafael A Maceira
# 186001      0                                 Elsa Frettem
# 186002      1                                keshia ashton
# 186003      2                                        Cindy
# 186004      3                            Jezarae Dominguez
# 186005      0                               Johnny Saigon®
# 186006      0                               Johnny Saigon®
# 186007      0                               Johnny Saigon®
# 186008      0                                 Derick Smith
# 186009      1                             Cherylann Morris
# 186010      2                                      Dyan C.
# 186011      3                                       COre61
# 186012      4                                  Dede Sofyan
# 186013      5                                       Dave C
# 186014      6                                         Zion
# 186015      7                              Barrie J. Lynch
#
#                                                   Content               Date  \
# 0       Product came exactly as described and would re...     March 10, 2014
# 1       I am very pleased with the phone we received. ...     March 27, 2014
# 2       The Samsung Galazy S3 is one of the best phone...      April 3, 2014
# 3       The television was a refurbished one, and for ...     April 13, 2014
# 4       Delivery was very prompt.  The picture of this...      April 1, 2014
# 5       This phone is the biggest piece of junk I have...  December 28, 2011
# 6       From the Moment I opened the box, I fell head ...  November 15, 2010
# 7       I purchased this phone thinking it was brand n...        May 1, 2012
# 8       This was a great phone - everything I wanted, ...   December 2, 2010
# 9       I chose a 5 star rate for this seller because ...   October 11, 2013
# 10      Used it for a year in 2006 and it was rugged a...     April 25, 2013
# 11      not working after a few 2 month with minimal u...      June 19, 2012
# 12      Phone arrived in good condition worked well wh...  February 11, 2012
# 13      Quick delivery, phone is great.  Exactly what ...   January 12, 2012
# 14      Love the qwerty keyboard. wish the messaging w...  December 23, 2011
# 15      This phone did not work at all when I received...  February 19, 2012
# 16      I would like to have or to see the reall case ...     March 26, 2012
# 17      For starters is a great looking TV (on the out...      June 19, 2000
# 18      I found the Sony KV-53S65 53" Projection TV to...      June 17, 2000
# 19      This TV has a great picture quality.  The pict...      June 17, 2000
# 20      This is a great TV. Whenever I think of buying...      June 16, 2000
# 21      I just bought one and found it a nice match wi...      June 17, 2000
# 22      The TV is a good one and I am very satisified ...      June 13, 2000
# 23      If you need to have a big TV to see all your f...      June 17, 2000
# 24      I love it except that it is too big for my sma...      July 17, 2002
# 25      What do you want from your phone?I'm a bit of ...   October 18, 2003
# 26      I do not like the phone because it only holds ...  December 11, 2003
# 27      Wow!  What a spectacular phone!  From clarity ...   December 2, 2003
# 28      I've owned this phone for several months now, ...   October 22, 2003
# 29      The phone is great.  I would recommend it to f...   December 8, 2003
# ...                                                   ...                ...
# 185986  Love the Dual Sim capabilities, bought this fo...     August 6, 2013
# 185987  The phone overall, is good but when the phone ...  February 17, 2014
# 185988  A common complaint about this phone is that wh...       May 25, 2013
# 185989  I ordered this phone from another site. I have...     March 28, 2013
# 185990  First off, I am not a professional reviewer, n...      April 7, 2014
# 185991  I saw all the answer and questions and all the...       May 27, 2014
# 185992  i love my Samsung Galaxy S5 SM-G900F 4G LTE 16...       June 9, 2014
# 185993  The seller was very professional and prompt. T...       June 7, 2014
# 185994  All features off the phone work properlyNo fai...       May 23, 2014
# 185995  amazing phone, amazing display and camera, som...       June 9, 2014
# 185996  excellent, everything went well the product me...       June 8, 2014
# 185997  The seller shipped the phone just a few hours ...       May 29, 2014
# 185998  Hate it! Hate it! Hate it!!!!!What a stupid de...       May 30, 2014
# 185999  My samsung galaxy s5 is a very good phone.Is e...       May 19, 2014
# 186000  Obviously more of the same, same finishes not ...       June 1, 2014
# 186001  Although still too large, this is a nice one. ...   February 6, 2014
# 186002  Did not work for my service like they said it ...     March 21, 2014
# 186003  every thing is good except for the power butto...     March 17, 2014
# 186004  it's keep fforcing everything to close, flash ...     March 16, 2014
# 186005  First off, I am not a professional reviewer, n...      April 9, 2014
# 186006  First off, I am not a professional reviewer, n...      April 9, 2014
# 186007  First off, I am not a professional reviewer, n...     April 11, 2014
# 186008  So far only AT&T; and [T-Mobile]* support the ...   January 19, 2014
# 186009  So Far i am in love with this phone it works w...  February 13, 2014
# 186010  Great!!!  phone for the price it is very sensi...      April 9, 2014
# 186011  I just  bought this phone and I really like it...     March 29, 2014
# 186012  High quality smartphone,I really like it..I wi...     April 25, 2014
# 186013  I bought this phone since I had had luck with ...      April 7, 2014
# 186014  I actually haven't have the phone yet, but hea...        May 1, 2014
# 186015  It was not as advertised.  It would not send o...     April 13, 2014
#
#                                                  Features  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# 5       Predictive text input anticipates what you're ...
# 6       Predictive text input anticipates what you're ...
# 7       Predictive text input anticipates what you're ...
# 8       Predictive text input anticipates what you're ...
# 9       Predictive text input anticipates what you're ...
# 10      Predictive text input anticipates what you're ...
# 11      Predictive text input anticipates what you're ...
# 12      Predictive text input anticipates what you're ...
# 13      Predictive text input anticipates what you're ...
# 14      Predictive text input anticipates what you're ...
# 15      Predictive text input anticipates what you're ...
# 16      Predictive text input anticipates what you're ...
# 17      53-inch big-screen television; 55.6 x 48 x 24....
# 18      53-inch big-screen television; 55.6 x 48 x 24....
# 19      53-inch big-screen television; 55.6 x 48 x 24....
# 20      53-inch big-screen television; 55.6 x 48 x 24....
# 21      53-inch big-screen television; 55.6 x 48 x 24....
# 22      53-inch big-screen television; 55.6 x 48 x 24....
# 23      53-inch big-screen television; 55.6 x 48 x 24....
# 24      53-inch big-screen television; 55.6 x 48 x 24....
# 25                                                   None
# 26                                                   None
# 27                                                   None
# 28                                                   None
# 29                                                   None
# ...                                                   ...
# 185986  Android OS w/ Google Play Store\nQuad Band: GS...
# 185987  Android OS w/ Google Play Store\nQuad Band: GS...
# 185988  Android OS w/ Google Play Store\nQuad Band: GS...
# 185989  Android OS w/ Google Play Store\nQuad Band: GS...
# 185990                                               None
# 185991                                               None
# 185992                                               None
# 185993                                               None
# 185994                                               None
# 185995                                               None
# 185996                                               None
# 185997                                               None
# 185998                                               None
# 185999                                               None
# 186000                                               None
# 186001                                               None
# 186002                                               None
# 186003                                               None
# 186004                                               None
# 186005                                               None
# 186006                                               None
# 186007                                               None
# 186008  5.0 inch large capacitive screen with 960*540 ...
# 186009  5.0 inch large capacitive screen with 960*540 ...
# 186010  5.0 inch large capacitive screen with 960*540 ...
# 186011  5.0 inch large capacitive screen with 960*540 ...
# 186012  5.0 inch large capacitive screen with 960*540 ...
# 186013  5.0 inch large capacitive screen with 960*540 ...
# 186014  5.0 inch large capacitive screen with 960*540 ...
# 186015  5.0 inch large capacitive screen with 960*540 ...
#
#                                                    ImgURL  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# 5       http://ecx.images-amazon.com/images/I/412FfxHo...
# 6       http://ecx.images-amazon.com/images/I/412FfxHo...
# 7       http://ecx.images-amazon.com/images/I/412FfxHo...
# 8       http://ecx.images-amazon.com/images/I/412FfxHo...
# 9       http://ecx.images-amazon.com/images/I/412FfxHo...
# 10      http://ecx.images-amazon.com/images/I/412FfxHo...
# 11      http://ecx.images-amazon.com/images/I/412FfxHo...
# 12      http://ecx.images-amazon.com/images/I/412FfxHo...
# 13      http://ecx.images-amazon.com/images/I/412FfxHo...
# 14      http://ecx.images-amazon.com/images/I/412FfxHo...
# 15      http://ecx.images-amazon.com/images/I/412FfxHo...
# 16      http://ecx.images-amazon.com/images/I/412FfxHo...
# 17      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 18      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 19      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 20      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 21      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 22      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 23      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 24      http://ecx.images-amazon.com/images/I/51RPD2TK...
# 25      http://ecx.images-amazon.com/images/I/4111M55Y...
# 26      http://ecx.images-amazon.com/images/I/4111M55Y...
# 27      http://ecx.images-amazon.com/images/I/4111M55Y...
# 28      http://ecx.images-amazon.com/images/I/4111M55Y...
# 29      http://ecx.images-amazon.com/images/I/4111M55Y...
# ...                                                   ...
# 185986  http://ecx.images-amazon.com/images/I/41M6yFYx...
# 185987  http://ecx.images-amazon.com/images/I/41M6yFYx...
# 185988  http://ecx.images-amazon.com/images/I/41M6yFYx...
# 185989  http://ecx.images-amazon.com/images/I/41M6yFYx...
# 185990  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185991  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185992  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185993  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185994  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185995  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185996  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185997  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185998  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 185999  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 186000  http://ecx.images-amazon.com/images/I/41Y%2BlQ...
# 186001                                               None
# 186002                                               None
# 186003                                               None
# 186004                                               None
# 186005                                               None
# 186006                                               None
# 186007                                               None
# 186008  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186009  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186010  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186011  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186012  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186013  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186014  http://ecx.images-amazon.com/images/I/41OprWWf...
# 186015  http://ecx.images-amazon.com/images/I/41OprWWf...
#
#                                                      Name Overall  \
# 0                                                    None     5.0
# 1                                                    None     5.0
# 2                                                    None     5.0
# 3                                                    None     4.0
# 4                                                    None     4.0
# 5       HTC Dash / S620 / S621 (Excalibur) Black Windo...     1.0
# 6       HTC Dash / S620 / S621 (Excalibur) Black Windo...     5.0
# 7       HTC Dash / S620 / S621 (Excalibur) Black Windo...     1.0
# 8       HTC Dash / S620 / S621 (Excalibur) Black Windo...     3.0
# 9       HTC Dash / S620 / S621 (Excalibur) Black Windo...     5.0
# 10      HTC Dash / S620 / S621 (Excalibur) Black Windo...     5.0
# 11      HTC Dash / S620 / S621 (Excalibur) Black Windo...     1.0
# 12      HTC Dash / S620 / S621 (Excalibur) Black Windo...     4.0
# 13      HTC Dash / S620 / S621 (Excalibur) Black Windo...     5.0
# 14      HTC Dash / S620 / S621 (Excalibur) Black Windo...     4.0
# 15      HTC Dash / S620 / S621 (Excalibur) Black Windo...     1.0
# 16      HTC Dash / S620 / S621 (Excalibur) Black Windo...     3.0
# 17                        Sony KP-53S65 53" Projection TV     4.0
# 18                        Sony KP-53S65 53" Projection TV     4.0
# 19                        Sony KP-53S65 53" Projection TV     5.0
# 20                        Sony KP-53S65 53" Projection TV     5.0
# 21                        Sony KP-53S65 53" Projection TV     4.0
# 22                        Sony KP-53S65 53" Projection TV     4.0
# 23                        Sony KP-53S65 53" Projection TV     5.0
# 24                        Sony KP-53S65 53" Projection TV     5.0
# 25                          Motorola i95cl Phone (Nextel)     4.0
# 26                          Motorola i95cl Phone (Nextel)     1.0
# 27                          Motorola i95cl Phone (Nextel)     5.0
# 28                          Motorola i95cl Phone (Nextel)     4.0
# 29                          Motorola i95cl Phone (Nextel)     4.0
# ...                                                   ...     ...
# 185986  SVP S580 THE 5-inch Dual SIM Android WiFi Smar...     4.0
# 185987  SVP S580 THE 5-inch Dual SIM Android WiFi Smar...     3.0
# 185988  SVP S580 THE 5-inch Dual SIM Android WiFi Smar...     4.0
# 185989  SVP S580 THE 5-inch Dual SIM Android WiFi Smar...     2.0
# 185990  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 185991  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     1.0
# 185992  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 185993  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 185994  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 185995  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 185996  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 185997  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     4.0
# 185998  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     1.0
# 185999  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     5.0
# 186000  Samsung Galaxy S5 SM-G900F 4G LTE 16GB BLACK -...     3.0
# 186001                                               None     5.0
# 186002                                               None     1.0
# 186003                                               None     4.0
# 186004                                               None     2.0
# 186005                                               None     5.0
# 186006                                               None     5.0
# 186007                                               None     5.0
# 186008  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     5.0
# 186009  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     5.0
# 186010  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     4.0
# 186011  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     5.0
# 186012  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     5.0
# 186013  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     2.0
# 186014  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     4.0
# 186015  CUBOT P9 5.0" Capacitive Touch Screen MTK6572A...     3.0
#
#               Price   ProductID        ReviewID  \
# 0              None  1466736038   RYYNWQWW6LAC1
# 1              None  1466736038  R2G160TW2JWGD8
# 2              None  1466736038  R3P9IS2JNG68K2
# 3              None  8987029395  R3LDJA7HU2Q0FS
# 4              None  8987029395   RAQB0MR9LGA2G
# 5       Unavailable  9043435856  R2SNXGY9Z3IRMR
# 6       Unavailable  9043435856   RI8F7YL5KZ7TB
# 7       Unavailable  9043435856   RBJOWI21FRE27
# 8       Unavailable  9043435856  R1R4VRGK2UTSYU
# 9       Unavailable  9043435856  R1W6Y4BC52PWSI
# 10      Unavailable  9043435856  R30Z5FQESV4QA0
# 11      Unavailable  9043435856  R1ZXYM7854OPM8
# 12      Unavailable  9043435856  R1LIQTS8BI8YDL
# 13      Unavailable  9043435856  R35LTEQ9WZGRYV
# 14      Unavailable  9043435856  R1QDNG3VDH2QVN
# 15      Unavailable  9043435856  R1KOG7QVBLCM5H
# 16      Unavailable  9043435856   RH3V71CZH4Q8E
# 17      Unavailable  B00000K3X3  R2PN13IMBKBDR6
# 18      Unavailable  B00000K3X3  R2CV5HQAMLF1PJ
# 19      Unavailable  B00000K3X3   R7GOZBR9A2RVF
# 20      Unavailable  B00000K3X3  R37KG9WFRHRYCC
# 21      Unavailable  B00000K3X3  R39YJKVPUT5WXV
# 22      Unavailable  B00000K3X3  R3CHDTGI2O7N4U
# 23      Unavailable  B00000K3X3  R3S5ZF2YVC1ORB
# 24      Unavailable  B00000K3X3  R25WRWKIBDH7MP
# 25      Unavailable  B00006J9HH  R1WX3XETSA9ETE
# 26      Unavailable  B00006J9HH   RANRLKQOA41E6
# 27      Unavailable  B00006J9HH  R35M3KAOFTL8FY
# 28      Unavailable  B00006J9HH  R30E6VC6NPCQVE
# 29      Unavailable  B00006J9HH  R2SEOPS5FGPSXK
# ...             ...         ...             ...
# 185986       $54.00  B00JBPE9AW   RMLWE05YGPNCC
# 185987       $54.00  B00JBPE9AW  R3JP0EKY3G8G7G
# 185988       $54.00  B00JBPE9AW  R2IRJEAIRDXOHS
# 185989       $54.00  B00JBPE9AW  R1TMYQTSZEYZZT
# 185990      $679.89  B00JFNDLRC  R34LNYWMRW24F4
# 185991      $679.89  B00JFNDLRC  R2BVU5FMM9OIXF
# 185992      $679.89  B00JFNDLRC  R28IMEO0HVRPFV
# 185993      $679.89  B00JFNDLRC  R2OCRKCJGNR5R4
# 185994      $679.89  B00JFNDLRC  R3EY3QYEQT7TJ2
# 185995      $679.89  B00JFNDLRC  R36JSRW156XNCY
# 185996      $679.89  B00JFNDLRC  R3N2U81OSHLCXN
# 185997      $679.89  B00JFNDLRC   RMFOY2VF0S32C
# 185998      $679.89  B00JFNDLRC   RY1T827ZX4UTT
# 185999      $679.89  B00JFNDLRC   RLB8H5Q24VMVW
# 186000      $679.89  B00JFNDLRC   RVQBMDTMIKC76
# 186001         None  B00JFYXL5I  R3QVT2K37D2KBH
# 186002         None  B00JFYXL5I  R1VHLYPDFY8YR6
# 186003         None  B00JFYXL5I  R2W5BGMY94LM4W
# 186004         None  B00JFYXL5I  R18O2F73E8KUMI
# 186005         None  B00JH1O7TI   RGHPC6H6A4HOR
# 186006         None  B00JKQCYNQ  R36MYRPN1TTA3W
# 186007         None  B00JLSBQ3W  R2I8IKG0UWIG35
# 186008      $119.99  B00JP6PGTU  R2HXRYPLU23FU8
# 186009      $119.99  B00JP6PGTU  R2MU0ANT60PR4V
# 186010      $119.99  B00JP6PGTU  R1FNHTMVSL7RV0
# 186011      $119.99  B00JP6PGTU  R10XTTJTENA5HL
# 186012      $119.99  B00JP6PGTU   RX14H9B2RFQID
# 186013      $119.99  B00JP6PGTU   R1TEI321M6L4K
# 186014      $119.99  B00JP6PGTU   R8PR1WVSCR3GO
# 186015      $119.99  B00JP6PGTU   RP6KYN4EUVG25
#
#                                                     Title
# 0                                                   Great
# 1                                        Excellent phone.
# 2                          As described and a great phone
# 3                           nice television for the price
# 4                  Service and product quality very good.
# 5                                           Don't buy it!
# 6       Great Buy if you don't want to be Suckered int...
# 7                                   Phone was refurbished
# 8                                         No touch screen
# 9               This company is GREAT to do business with
# 10                Used it for a year and was very good...
# 11                                            not working
# 12                                             Good phone
# 13                                            Great phone
# 14                                          Nice and Easy
# 15      HTC Dash/S620/S621 Excalibur Black Windows WI-...
# 16      I would like more information about the item a...
# 17                Great TV set and really good Image but!
# 18                                Good value for the cost
# 19                                            A great TV!
# 20                                It looks like real life
# 21                                        High quality TV
# 22                            Well worth it for the price
# 23                                        A fantastic TV!
# 24                                               Great TV
# 25          Expensive, but full featured and high quality
# 26         Amazon and Nextel do not partner well together
# 27              Nextel is definitely the Best of the Best
# 28                                         Great Phone...
# 29                                                    ...
# ...                                                   ...
# 185986                     Love the Dual Sim capabilities
# 185987                            Phone doesn't charge...
# 185988                                GPS Works...sort of
# 185989  Fast, but keyboard is way too small for me to use
# 185990                                A Samsung Evolution
# 185991                         It was NOT the right model
# 185992                                         good phone
# 185993                                     The very Best!
# 185994                       excelent phone no complaints
# 185995                                      amazing phone
# 185996                           Excellent mobile device.
# 185997                 Great features.  Pretty expensive.
# 185998                                           Hate it!
# 185999                                          Very good
# 186000                                              Is ok
# 186001                                        Nice phone!
# 186002                                            unhappy
# 186003                                          good deal
# 186004                                    i'm disapointed
# 186005                                A Samsung Evolution
# 186006                                A Samsung Evolution
# 186007                                A Samsung Evolution
# 186008                                         Super fast
# 186009                        Great phone and Great Price
# 186010                           cubot p9 excellent phone
# 186011                                        great value
# 186012                                            Amazing
# 186013                     Used for 2 hours then returned
# 186014                                         Good phone
# 186015                                              Cubot
#
# [186016 rows x 12 columns]

# %% [markdown]
# ### Saving the Dataframe for reusability

# %%
# SAVING THE DATAFRAME
Final_df1.to_pickle('full_dataset/full_dataset')
